# %%
import pandas as pd
import seaborn as sns

# %%
df_pred = pd.read_csv('samplePredictions.csv')
df_pred
# Out:
#              X         Y  prediction
# 0     0.184414 -0.435699           2
# 1    -0.254289 -0.907349           2
# 2     0.173059  0.672055           1
# 3    -0.338732 -0.207426           1
# 4    -0.837849  0.785542           1
# ...        ...       ...         ...
# 3995 -0.086429 -0.498273           3
# 3996  0.889088 -0.919918           2
# 3997  0.498285 -0.817070           2
# 3998  0.907234 -0.711062           2
# 3999  0.113035 -0.826052           3
#
# [4000 rows x 3 columns]

# %%
df_test = pd.read_csv('data_test.csv')
df_test
# Out:
#             x1        x2  category
# 0     0.184414 -0.435699         1
# 1    -0.254289 -0.907349         3
# 2     0.173059  0.672055         1
# 3    -0.338732 -0.207426         1
# 4    -0.837849  0.785542         1
# ...        ...       ...       ...
# 3995 -0.086429 -0.498273         1
# 3996  0.889088 -0.919918         3
# 3997  0.498285 -0.817070         2
# 3998  0.907234 -0.711062         3
# 3999  0.113035 -0.826052         3
#
# [4000 rows x 3 columns]

# %%
df_test['output'] = np.where(df_test['category'] == df_pred['prediction'], 'True', 'False')

# %%
filtered_label0 = df_test[df_test['output'] == 'False']
filtered_label1 = df_test[df_test['output'] == 'True']

# %%
sns.scatterplot(x='x1',y='x2',hue='category',data=df_test,style='output',palette='gist_rainbow')
# Out:
# <AxesSubplot:xlabel='x1', ylabel='x2'>
